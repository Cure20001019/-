# %%
# %load 2-rename.py
import os
import argparse

def rename_image(src_dir, date, name):
    i = 0
    sub_dirs = os.listdir(src_dir)
    for sub_dir in sub_dirs:
        if not os.path.isdir(os.path.join(src_dir, sub_dir)):
            print("{} isn't subdir. Skipped it.".format(sub_dir))
            continue
        else:
            num = 1
            for image in os.listdir(os.path.join(src_dir, sub_dir)):
                org_name, ext = image.split(sep=".", maxsplit=1)
                os.rename(os.path.join(src_dir, sub_dir, image), \
                        os.path.join(src_dir, sub_dir, "{}_{}_{:04}.{}".format(date, name, num, ext))) 
                num += 1
            i+=1
        print("{} done".format(sub_dir))
    print("{} folders renamed in total.".format(i))


if __name__ == "__main__":
    parser = argparse.ArgumentParser(description='A batch file-renaming script.')
    parser.add_argument('--date', type=str, metavar='S',
                        help="Shooting time.")
    parser.add_argument('--name', type=str, metavar='S',
                        help="Your name.")
    args,unknown = parser.parse_known_args(['--date=20210702','--name=朱轩汉'])
    
    src_dir = r'C:\Users\air10\Desktop\New Data_edited'

    rename_image(src_dir, args.date, args.name)
# Out:
# Namespace(date='20210702', name='朱轩汉')
# 10_北田径场_E done
# 10_北田径场_N done
# 10_北田径场_S done
# 10_北田径场_W done
# 11_信息楼_E done
# 11_信息楼_N done
# 11_信息楼_S done
# 11_信息楼_W done
# 12_第三教学楼_E done
# 12_第三教学楼_N done
# 12_第三教学楼_S done
# 12_第三教学楼_W done
# 13_知新园_E done
# 13_知新园_N done
# 13_知新园_S done
# 13_知新园_W done
# 14_南田径场_E done
# 14_南田径场_N done
# 14_南田径场_S done
# 14_南田径场_W done
# 15_第四教学楼_SW done
# 15_第四教学楼_理科楼_N done
# 16_艺术楼_S done
# 16_艺术楼_W done
# 17_北图书馆_E done
# 17_北图书馆_N done
# 17_北图书馆_S done
# 18_理科楼_S done
# 18_理科楼_W done
# 18_理科楼_生命楼_环能楼_E done
# 19_经管楼_E done
# 19_经管楼_N done
# 19_经管楼_S done
# 19_经管楼_W done
# 1_第一教学楼_E done
# 1_第一教学楼_N done
# 1_第一教学楼_S done
# 1_第一教学楼_W done
# 20_工大建国饭店_E done
# 20_工大建国饭店_N done
# 20_工大建国饭店_S done
# 20_工大建国饭店_W done
# 21_科学楼_E done
# 21_科学楼_N done
# 21_科学楼_S done
# 21_科学楼_W done
# 22_人文楼_E done
# 22_人文楼_N done
# 22_人文楼_S done
# 22_人文楼_W done
# 23_奥林匹克体育馆_N done
# 23_奥林匹克体育馆_SE done
# 23_奥林匹克体育馆_W done
# 24_月亮湖_E done
# 24_月亮湖_N done
# 24_月亮湖_S done
# 24_月亮湖_W done
# 25_软件楼_W done
# 26_城建楼_W done
# 27_实训楼_N done
# 27_实训楼_W done
# 28_美食园_S done
# 28_美食园_W done
# 29_奥运餐厅_E done
# 29_奥运餐厅_N done
# 29_奥运餐厅_S done
# 2_第二教学楼_E done
# 2_第二教学楼_W done
# 30_学生综合服务中心_E done
# 30_学生综合服务中心_S done
# 30_学生综合服务中心_W done
# 31_生命楼_W done
# 32_能源楼_N done
# 32_能源楼_S done
# 32_能源楼_W done
# 33_环能楼_S done
# 34_机电楼_E done
# 34_机电楼_S done
# 34_机电楼_W done
# 35_基础楼_E done
# 35_基础楼_S done
# 35_基础楼_W done
# 36_水环境楼_E done
# 36_水环境楼_S done
# 37_建工西楼_E done
# 37_建工西楼_N done
# 37_建工西楼_W done
# 38_保卫处_N done
# 38_保卫处_S done
# 38_保卫处_W done
# 39_汲学楼_E done
# 39_汲学楼_N done
# 39_汲学楼_S done
# 39_汲学楼_W done
# 3_材料楼_E done
# 3_材料楼_N done
# 3_材料楼_S done
# 3_材料楼_W done
# 40_第四教学楼_N done
# 40_第四教学楼_S done
# 41_第四报告厅_S done
# 41_第四报告厅_网络中心_E done
# 41_第四报告厅_网络中心_一教_W done
# 43_通州一教_E done
# 44_田园餐厅_E done
# 44_田园餐厅_NW done
# 44_田园餐厅_S done
# 45_耕园图书馆_N done
# 45_耕园图书馆_S done
# 45_耕园图书馆_W done
# 46_跆拳道馆_E done
# 46_跆拳道馆_N done
# 47_体育馆_E done
# 47_体育馆_N done
# 47_体育馆_S done
# 47_体育馆_W done
# 48_二教_三教_E done
# 48_二教_三教_W done
# 48_通州三教_N done
# 48_通州二教_S done
# 49_问渠楼_E done
# 49_问渠楼_N done
# 49_问渠楼_S done
# 49_问渠楼_W done
# 4_逸夫图书馆_E done
# 4_逸夫图书馆_N done
# 4_逸夫图书馆_S done
# 4_逸夫图书馆_W done
# 50_明德楼_E done
# 50_明德楼_N done
# 50_明德楼_S done
# 50_明德楼_W done
# 51_通州体育场_E done
# 51_通州体育场_W done
# 52_通州游泳馆_E done
# 52_通州游泳馆_S done
# 5_礼堂_E done
# 5_礼堂_N done
# 5_礼堂_W done
# 6_数理楼_E done
# 6_数理楼_N done
# 6_数理楼_S done
# 6_数理楼_W done
# 7_游泳馆_E done
# 7_游泳馆_N done
# 7_游泳馆_S done
# 7_游泳馆_W done
# 8_校医院_N done
# 8_校医院_S done
# 8_校医院_W done
# 9_金工楼_S done
# 9_金工楼_W done
# 152 folders renamed in total.
